# %%
# Import necessary libraries

import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from scipy.stats import spearmanr
import itertools
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import scipy.stats as stats

# %%
# Import the datasets
HouseTrain=pd.read_csv('/Users/plutobot/Downloads/Kaggle/HousingData/train.csv')

# %%
# Display all rows

pd.set_option('display.max_rows',None)

# %%
HouseTrain.count()
# Out:
# Id               1460
# MSSubClass       1460
# MSZoning         1460
# LotFrontage      1201
# LotArea          1460
# Street           1460
# Alley              91
# LotShape         1460
# LandContour      1460
# Utilities        1460
# LotConfig        1460
# LandSlope        1460
# Neighborhood     1460
# Condition1       1460
# Condition2       1460
# BldgType         1460
# HouseStyle       1460
# OverallQual      1460
# OverallCond      1460
# YearBuilt        1460
# YearRemodAdd     1460
# RoofStyle        1460
# RoofMatl         1460
# Exterior1st      1460
# Exterior2nd      1460
# MasVnrType       1452
# MasVnrArea       1452
# ExterQual        1460
# ExterCond        1460
# Foundation       1460
# BsmtQual         1423
# BsmtCond         1423
# BsmtExposure     1422
# BsmtFinType1     1423
# BsmtFinSF1       1460
# BsmtFinType2     1422
# BsmtFinSF2       1460
# BsmtUnfSF        1460
# TotalBsmtSF      1460
# Heating          1460
# HeatingQC        1460
# ...

# %%
# Make a copy of the dataset
HouseTrain1=HouseTrain.copy()

# %%
# Drop variables that have several missing values
HouseTrain1=HouseTrain1.drop(columns=['Alley','PoolQC','Fence','MiscFeature'])

# %%
HouseTrain1.count()
# Out:
# Id               1460
# MSSubClass       1460
# MSZoning         1460
# LotFrontage      1201
# LotArea          1460
# Street           1460
# LotShape         1460
# LandContour      1460
# Utilities        1460
# LotConfig        1460
# LandSlope        1460
# Neighborhood     1460
# Condition1       1460
# Condition2       1460
# BldgType         1460
# HouseStyle       1460
# OverallQual      1460
# OverallCond      1460
# YearBuilt        1460
# YearRemodAdd     1460
# RoofStyle        1460
# RoofMatl         1460
# Exterior1st      1460
# Exterior2nd      1460
# MasVnrType       1452
# MasVnrArea       1452
# ExterQual        1460
# ExterCond        1460
# Foundation       1460
# BsmtQual         1423
# BsmtCond         1423
# BsmtExposure     1422
# BsmtFinType1     1423
# BsmtFinSF1       1460
# BsmtFinType2     1422
# BsmtFinSF2       1460
# BsmtUnfSF        1460
# TotalBsmtSF      1460
# Heating          1460
# HeatingQC        1460
# CentralAir       1460
# ...

# %%
HouseTrain1.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# ...

# %%
# Cat variables cleanup

# %%
HouseTrain1['FireplaceQu'].value_counts()
# Out:
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: int64

# %%
# Replace missing fireplace quality with No fireplace - NOFP
HouseTrain1['FireplaceQu'].fillna("NOFP",inplace=True)

# %%
HouseTrain1['FireplaceQu'].value_counts()
# Out:
# NOFP    690
# Gd      380
# TA      313
# Fa       33
# Ex       24
# Po       20
# Name: FireplaceQu, dtype: int64

# %%
HouseTrain1.count()
# Out:
# Id               1460
# MSSubClass       1460
# MSZoning         1460
# LotFrontage      1201
# LotArea          1460
# Street           1460
# LotShape         1460
# LandContour      1460
# Utilities        1460
# LotConfig        1460
# LandSlope        1460
# Neighborhood     1460
# Condition1       1460
# Condition2       1460
# BldgType         1460
# HouseStyle       1460
# OverallQual      1460
# OverallCond      1460
# YearBuilt        1460
# YearRemodAdd     1460
# RoofStyle        1460
# RoofMatl         1460
# Exterior1st      1460
# Exterior2nd      1460
# MasVnrType       1452
# MasVnrArea       1452
# ExterQual        1460
# ExterCond        1460
# Foundation       1460
# BsmtQual         1423
# BsmtCond         1423
# BsmtExposure     1422
# BsmtFinType1     1423
# BsmtFinSF1       1460
# BsmtFinType2     1422
# BsmtFinSF2       1460
# BsmtUnfSF        1460
# TotalBsmtSF      1460
# Heating          1460
# HeatingQC        1460
# CentralAir       1460
# ...

# %%
HouseTrain1['GarageType'].value_counts()
# Out:
# Attchd     870
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64

# %%
HouseTrain1['GarageType'].fillna("NOGAR",inplace=True)

# %%
HouseTrain1['GarageType'].value_counts()
# Out:
# Attchd     870
# Detchd     387
# BuiltIn     88
# NOGAR       81
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64

# %%
HouseTrain1['GarageYrBlt']=HouseTrain1['GarageYrBlt'].fillna(1111)

# %%
HouseTrain1['GarageFinish'].value_counts()
# Out:
# Unf    605
# RFn    422
# Fin    352
# Name: GarageFinish, dtype: int64

# %%
HouseTrain1['GarageFinish'].fillna("NOGAR",inplace=True)

# %%
HouseTrain1['GarageFinish'].value_counts()
# Out:
# Unf      605
# RFn      422
# Fin      352
# NOGAR     81
# Name: GarageFinish, dtype: int64

# %%
HouseTrain1['GarageQual'].value_counts()
# Out:
# TA    1311
# Fa      48
# Gd      14
# Po       3
# Ex       3
# Name: GarageQual, dtype: int64

# %%
HouseTrain1['GarageQual'].fillna("NOGAR",inplace=True)

# %%
HouseTrain1['GarageQual'].value_counts()
# Out:
# TA       1311
# NOGAR      81
# Fa         48
# Gd         14
# Po          3
# Ex          3
# Name: GarageQual, dtype: int64

# %%
HouseTrain1['GarageCond'].value_counts()
# Out:
# TA    1326
# Fa      35
# Gd       9
# Po       7
# Ex       2
# Name: GarageCond, dtype: int64

# %%
HouseTrain1['GarageCond'].fillna("NOGAR",inplace=True)

# %%
HouseTrain1['GarageCond'].value_counts()
# Out:
# TA       1326
# NOGAR      81
# Fa         35
# Gd          9
# Po          7
# Ex          2
# Name: GarageCond, dtype: int64

# %%
HouseTrain1['LotFrontage']=HouseTrain1['LotFrontage'].fillna(0)

# %%
HouseTrain1['MasVnrType'].value_counts()
# Out:
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64

# %%
HouseTrain1.count()
# Out:
# Id               1460
# MSSubClass       1460
# MSZoning         1460
# LotFrontage      1460
# LotArea          1460
# Street           1460
# LotShape         1460
# LandContour      1460
# Utilities        1460
# LotConfig        1460
# LandSlope        1460
# Neighborhood     1460
# Condition1       1460
# Condition2       1460
# BldgType         1460
# HouseStyle       1460
# OverallQual      1460
# OverallCond      1460
# YearBuilt        1460
# YearRemodAdd     1460
# RoofStyle        1460
# RoofMatl         1460
# Exterior1st      1460
# Exterior2nd      1460
# MasVnrType       1452
# MasVnrArea       1452
# ExterQual        1460
# ExterCond        1460
# Foundation       1460
# BsmtQual         1423
# BsmtCond         1423
# BsmtExposure     1422
# BsmtFinType1     1423
# BsmtFinSF1       1460
# BsmtFinType2     1422
# BsmtFinSF2       1460
# BsmtUnfSF        1460
# TotalBsmtSF      1460
# Heating          1460
# HeatingQC        1460
# CentralAir       1460
# ...

# %%
HouseTrain1=HouseTrain1.dropna()

# %%
len(HouseTrain1)
# Out:
# 1412

# %%
# Make a copy of the cleaned up dataset
HouseTrain2=HouseTrain1.copy()

# %%
HouseTrain2['GarageYrBlt']=HouseTrain2['GarageYrBlt'].astype(float).astype(int)

# %%
# Removing the variables that are not needed because there are no categories
HouseTrain2=HouseTrain2.drop(columns=['Utilities'])

# %%
# Convert the dtype object to cat. This will help in label encoding the cat variables
HouseTrain2['MSZoning'] = HouseTrain2['MSZoning'].astype('category')
HouseTrain2['Street'] = HouseTrain2['Street'].astype('category')
HouseTrain2['LotShape'] = HouseTrain2['LotShape'].astype('category')
HouseTrain2['LandContour'] = HouseTrain2['LandContour'].astype('category')
HouseTrain2['LotConfig'] = HouseTrain2['LotConfig'].astype('category')
HouseTrain2['LandSlope'] = HouseTrain2['LandSlope'].astype('category')
HouseTrain2['Neighborhood'] = HouseTrain2['Neighborhood'].astype('category')
HouseTrain2['Condition1'] = HouseTrain2['Condition1'].astype('category')
HouseTrain2['Condition2'] = HouseTrain2['Condition2'].astype('category')
HouseTrain2['BldgType'] = HouseTrain2['BldgType'].astype('category')
HouseTrain2['HouseStyle'] = HouseTrain2['HouseStyle'].astype('category')
HouseTrain2['RoofStyle'] = HouseTrain2['RoofStyle'].astype('category')
HouseTrain2['RoofMatl'] = HouseTrain2['RoofMatl'].astype('category')
HouseTrain2['Exterior1st'] = HouseTrain2['Exterior1st'].astype('category')
HouseTrain2['Exterior2nd'] = HouseTrain2['Exterior2nd'].astype('category')
HouseTrain2['MasVnrType'] = HouseTrain2['MasVnrType'].astype('category')
HouseTrain2['ExterQual'] = HouseTrain2['ExterQual'].astype('category')
HouseTrain2['ExterCond'] = HouseTrain2['ExterCond'].astype('category')
HouseTrain2['Foundation'] = HouseTrain2['Foundation'].astype('category')
HouseTrain2['BsmtQual'] = HouseTrain2['BsmtQual'].astype('category')
HouseTrain2['BsmtCond'] = HouseTrain2['BsmtCond'].astype('category')
HouseTrain2['BsmtExposure'] = HouseTrain2['BsmtExposure'].astype('category')
HouseTrain2['BsmtFinType1'] = HouseTrain2['BsmtFinType1'].astype('category')
HouseTrain2['BsmtFinType2'] = HouseTrain2['BsmtFinType2'].astype('category')
HouseTrain2['Heating'] = HouseTrain2['Heating'].astype('category')
HouseTrain2['HeatingQC'] = HouseTrain2['HeatingQC'].astype('category')
HouseTrain2['CentralAir'] = HouseTrain2['CentralAir'].astype('category')
HouseTrain2['Electrical'] = HouseTrain2['Electrical'].astype('category')
HouseTrain2['KitchenQual'] = HouseTrain2['KitchenQual'].astype('category')
HouseTrain2['Functional'] = HouseTrain2['Functional'].astype('category')
HouseTrain2['FireplaceQu'] = HouseTrain2['FireplaceQu'].astype('category')
HouseTrain2['GarageType'] = HouseTrain2['GarageType'].astype('category')
HouseTrain2['GarageFinish'] = HouseTrain2['GarageFinish'].astype('category')
HouseTrain2['GarageQual'] = HouseTrain2['GarageQual'].astype('category')
HouseTrain2['GarageCond'] = HouseTrain2['GarageCond'].astype('category')
HouseTrain2['PavedDrive'] = HouseTrain2['PavedDrive'].astype('category')
HouseTrain2['SaleType'] = HouseTrain2['SaleType'].astype('category')
HouseTrain2['SaleCondition'] = HouseTrain2['SaleCondition'].astype('category')

# %%
# Label encoding
HouseTrain2['MSZoning'] = HouseTrain2['MSZoning'].cat.codes
HouseTrain2['Street'] = HouseTrain2['Street'].cat.codes
HouseTrain2['LotShape'] = HouseTrain2['LotShape'].cat.codes
HouseTrain2['LandContour'] = HouseTrain2['LandContour'].cat.codes
HouseTrain2['LotConfig'] = HouseTrain2['LotConfig'].cat.codes
HouseTrain2['LandSlope'] = HouseTrain2['LandSlope'].cat.codes
HouseTrain2['Neighborhood'] = HouseTrain2['Neighborhood'].cat.codes
HouseTrain2['Condition1'] = HouseTrain2['Condition1'].cat.codes
HouseTrain2['Condition2'] = HouseTrain2['Condition2'].cat.codes
HouseTrain2['BldgType'] = HouseTrain2['BldgType'].cat.codes
HouseTrain2['HouseStyle'] = HouseTrain2['HouseStyle'].cat.codes
HouseTrain2['RoofStyle'] = HouseTrain2['RoofStyle'].cat.codes
HouseTrain2['RoofMatl'] = HouseTrain2['RoofMatl'].cat.codes
HouseTrain2['Exterior1st'] = HouseTrain2['Exterior1st'].cat.codes
HouseTrain2['Exterior2nd'] = HouseTrain2['Exterior2nd'].cat.codes
HouseTrain2['MasVnrType'] = HouseTrain2['MasVnrType'].cat.codes
HouseTrain2['ExterQual'] = HouseTrain2['ExterQual'].cat.codes
HouseTrain2['ExterCond'] = HouseTrain2['ExterCond'].cat.codes
HouseTrain2['Foundation'] = HouseTrain2['Foundation'].cat.codes
HouseTrain2['BsmtQual'] = HouseTrain2['BsmtQual'].cat.codes
HouseTrain2['BsmtCond'] = HouseTrain2['BsmtCond'].cat.codes
HouseTrain2['BsmtExposure'] = HouseTrain2['BsmtExposure'].cat.codes
HouseTrain2['BsmtFinType1'] = HouseTrain2['BsmtFinType1'].cat.codes
HouseTrain2['BsmtFinType2'] = HouseTrain2['BsmtFinType2'].cat.codes
HouseTrain2['Heating'] = HouseTrain2['Heating'].cat.codes
HouseTrain2['HeatingQC'] = HouseTrain2['HeatingQC'].cat.codes
HouseTrain2['CentralAir'] = HouseTrain2['CentralAir'].cat.codes
HouseTrain2['Electrical'] = HouseTrain2['Electrical'].cat.codes
HouseTrain2['KitchenQual'] = HouseTrain2['KitchenQual'].cat.codes
HouseTrain2['Functional'] = HouseTrain2['Functional'].cat.codes
HouseTrain2['FireplaceQu'] = HouseTrain2['FireplaceQu'].cat.codes
HouseTrain2['GarageType'] = HouseTrain2['GarageType'].cat.codes
HouseTrain2['GarageFinish'] = HouseTrain2['GarageFinish'].cat.codes
HouseTrain2['GarageQual'] = HouseTrain2['GarageQual'].cat.codes
HouseTrain2['GarageCond'] = HouseTrain2['GarageCond'].cat.codes
HouseTrain2['PavedDrive'] = HouseTrain2['PavedDrive'].cat.codes
HouseTrain2['SaleType'] = HouseTrain2['SaleType'].cat.codes
HouseTrain2['SaleCondition'] = HouseTrain2['SaleCondition'].cat.codes

# %%
HouseTrain2.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0   1          60         3         65.0     8450       1         3
# 1   2          20         3         80.0     9600       1         3
# 2   3          60         3         68.0    11250       1         0
# 3   4          70         3         60.0     9550       1         0
# 4   5          60         3         84.0    14260       1         0
#
#    LandContour  LotConfig  LandSlope    ...      EnclosedPorch  3SsnPorch  \
# 0            3          4          0    ...                  0          0
# 1            3          2          0    ...                  0          0
# 2            3          4          0    ...                  0          0
# 3            3          0          0    ...                272          0
# 4            3          2          0    ...                  0          0
#
#    ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  SaleType  SaleCondition  \
# ...

# %%
HouseTrain3=HouseTrain2.copy()

# %%
# Min-max data scaling(only for variables that were converted into cat codes)
HouseTrain3['MSZoning']= (HouseTrain3['MSZoning']-HouseTrain3['MSZoning'].min())/(HouseTrain3['MSZoning'].max()-HouseTrain3['MSZoning'].min())
HouseTrain3['Street']= (HouseTrain3['Street']-HouseTrain3['Street'].min())/(HouseTrain3['Street'].max()-HouseTrain3['Street'].min())
HouseTrain3['LotShape']= (HouseTrain3['LotShape']-HouseTrain3['LotShape'].min())/(HouseTrain3['LotShape'].max()-HouseTrain3['LotShape'].min())
HouseTrain3['LandContour']= (HouseTrain3['LandContour']-HouseTrain3['LandContour'].min())/(HouseTrain3['LandContour'].max()-HouseTrain3['LandContour'].min())
HouseTrain3['LotConfig']= (HouseTrain3['LotConfig']-HouseTrain3['LotConfig'].min())/(HouseTrain3['LotConfig'].max()-HouseTrain3['LotConfig'].min())
HouseTrain3['LandSlope']= (HouseTrain3['LandSlope']-HouseTrain3['LandSlope'].min())/(HouseTrain3['LandSlope'].max()-HouseTrain3['LandSlope'].min())
HouseTrain3['Neighborhood']= (HouseTrain3['Neighborhood']-HouseTrain3['Neighborhood'].min())/(HouseTrain3['Neighborhood'].max()-HouseTrain3['Neighborhood'].min())
HouseTrain3['Condition1']= (HouseTrain3['Condition1']-HouseTrain3['Condition1'].min())/(HouseTrain3['Condition1'].max()-HouseTrain3['Condition1'].min())
HouseTrain3['Condition2']= (HouseTrain3['Condition2']-HouseTrain3['Condition2'].min())/(HouseTrain3['Condition2'].max()-HouseTrain3['Condition2'].min())
HouseTrain3['BldgType']= (HouseTrain3['BldgType']-HouseTrain3['BldgType'].min())/(HouseTrain3['BldgType'].max()-HouseTrain3['BldgType'].min())
HouseTrain3['HouseStyle']= (HouseTrain3['HouseStyle']-HouseTrain3['HouseStyle'].min())/(HouseTrain3['HouseStyle'].max()-HouseTrain3['HouseStyle'].min())
HouseTrain3['RoofStyle']= (HouseTrain3['RoofStyle']-HouseTrain3['RoofStyle'].min())/(HouseTrain3['RoofStyle'].max()-HouseTrain3['RoofStyle'].min())
HouseTrain3['RoofMatl']= (HouseTrain3['RoofMatl']-HouseTrain3['RoofMatl'].min())/(HouseTrain3['RoofMatl'].max()-HouseTrain3['RoofMatl'].min())
HouseTrain3['Exterior1st']= (HouseTrain3['Exterior1st']-HouseTrain3['Exterior1st'].min())/(HouseTrain3['Exterior1st'].max()-HouseTrain3['Exterior1st'].min())
HouseTrain3['Exterior2nd']= (HouseTrain3['Exterior2nd']-HouseTrain3['Exterior2nd'].min())/(HouseTrain3['Exterior2nd'].max()-HouseTrain3['Exterior2nd'].min())
HouseTrain3['MasVnrType']= (HouseTrain3['MasVnrType']-HouseTrain3['MasVnrType'].min())/(HouseTrain3['MasVnrType'].max()-HouseTrain3['MasVnrType'].min())
HouseTrain3['ExterQual']= (HouseTrain3['ExterQual']-HouseTrain3['ExterQual'].min())/(HouseTrain3['ExterQual'].max()-HouseTrain3['ExterQual'].min())
HouseTrain3['ExterCond']= (HouseTrain3['ExterCond']-HouseTrain3['ExterCond'].min())/(HouseTrain3['ExterCond'].max()-HouseTrain3['ExterCond'].min())
HouseTrain3['Foundation']= (HouseTrain3['Foundation']-HouseTrain3['Foundation'].min())/(HouseTrain3['Foundation'].max()-HouseTrain3['Foundation'].min())
HouseTrain3['BsmtQual']= (HouseTrain3['BsmtQual']-HouseTrain3['BsmtQual'].min())/(HouseTrain3['BsmtQual'].max()-HouseTrain3['BsmtQual'].min())
HouseTrain3['BsmtCond']= (HouseTrain3['BsmtCond']-HouseTrain3['BsmtCond'].min())/(HouseTrain3['BsmtCond'].max()-HouseTrain3['BsmtCond'].min())
HouseTrain3['BsmtExposure']= (HouseTrain3['BsmtExposure']-HouseTrain3['BsmtExposure'].min())/(HouseTrain3['BsmtExposure'].max()-HouseTrain3['BsmtExposure'].min())
HouseTrain3['BsmtFinType1']= (HouseTrain3['BsmtFinType1']-HouseTrain3['BsmtFinType1'].min())/(HouseTrain3['BsmtFinType1'].max()-HouseTrain3['BsmtFinType1'].min())
HouseTrain3['BsmtFinType2']= (HouseTrain3['BsmtFinType2']-HouseTrain3['BsmtFinType2'].min())/(HouseTrain3['BsmtFinType2'].max()-HouseTrain3['BsmtFinType2'].min())
HouseTrain3['Heating']= (HouseTrain3['Heating']-HouseTrain3['Heating'].min())/(HouseTrain3['Heating'].max()-HouseTrain3['Heating'].min())
HouseTrain3['HeatingQC']= (HouseTrain3['HeatingQC']-HouseTrain3['HeatingQC'].min())/(HouseTrain3['HeatingQC'].max()-HouseTrain3['HeatingQC'].min())
HouseTrain3['CentralAir']= (HouseTrain3['CentralAir']-HouseTrain3['CentralAir'].min())/(HouseTrain3['CentralAir'].max()-HouseTrain3['CentralAir'].min())
HouseTrain3['Electrical']= (HouseTrain3['Electrical']-HouseTrain3['Electrical'].min())/(HouseTrain3['Electrical'].max()-HouseTrain3['Electrical'].min())
HouseTrain3['KitchenQual']= (HouseTrain3['KitchenQual']-HouseTrain3['KitchenQual'].min())/(HouseTrain3['KitchenQual'].max()-HouseTrain3['KitchenQual'].min())
HouseTrain3['Functional']= (HouseTrain3['Functional']-HouseTrain3['Functional'].min())/(HouseTrain3['Functional'].max()-HouseTrain3['Functional'].min())
HouseTrain3['FireplaceQu']= (HouseTrain3['FireplaceQu']-HouseTrain3['FireplaceQu'].min())/(HouseTrain3['FireplaceQu'].max()-HouseTrain3['FireplaceQu'].min())
HouseTrain3['GarageType']= (HouseTrain3['GarageType']-HouseTrain3['GarageType'].min())/(HouseTrain3['GarageType'].max()-HouseTrain3['GarageType'].min())
HouseTrain3['GarageFinish']= (HouseTrain3['GarageFinish']-HouseTrain3['GarageFinish'].min())/(HouseTrain3['GarageFinish'].max()-HouseTrain3['GarageFinish'].min())
HouseTrain3['GarageQual']= (HouseTrain3['GarageQual']-HouseTrain3['GarageQual'].min())/(HouseTrain3['GarageQual'].max()-HouseTrain3['GarageQual'].min())
HouseTrain3['GarageCond']= (HouseTrain3['GarageCond']-HouseTrain3['GarageCond'].min())/(HouseTrain3['GarageCond'].max()-HouseTrain3['GarageCond'].min())
HouseTrain3['PavedDrive']= (HouseTrain3['PavedDrive']-HouseTrain3['PavedDrive'].min())/(HouseTrain3['PavedDrive'].max()-HouseTrain3['PavedDrive'].min())
HouseTrain3['SaleType']= (HouseTrain3['SaleType']-HouseTrain3['SaleType'].min())/(HouseTrain3['SaleType'].max()-HouseTrain3['SaleType'].min())
HouseTrain3['SaleCondition']= (HouseTrain3['SaleCondition']-HouseTrain3['SaleCondition'].min())/(HouseTrain3['SaleCondition'].max()-HouseTrain3['SaleCondition'].min())

# %%
HouseTrain3.head(20)
# Out:
#     Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0    1          60      0.75         65.0     8450     1.0  1.000000
# 1    2          20      0.75         80.0     9600     1.0  1.000000
# 2    3          60      0.75         68.0    11250     1.0  0.000000
# 3    4          70      0.75         60.0     9550     1.0  0.000000
# 4    5          60      0.75         84.0    14260     1.0  0.000000
# 5    6          50      0.75         85.0    14115     1.0  0.000000
# 6    7          20      0.75         75.0    10084     1.0  1.000000
# 7    8          60      0.75          0.0    10382     1.0  0.000000
# 8    9          50      1.00         51.0     6120     1.0  1.000000
# 9   10         190      0.75         50.0     7420     1.0  1.000000
# 10  11          20      0.75         70.0    11200     1.0  1.000000
# 11  12          60      0.75         85.0    11924     1.0  0.000000
# 12  13          20      0.75          0.0    12968     1.0  0.333333
# ...

# %%
# Converting the dataset HouseTrain3 into a csv file. This file will be used to perform univariate and bivariate analysis
HouseTrain3.to_csv('/Users/plutobot/Downloads/Kaggle/HousingData/train3.csv')

# %%
HouseTrain1.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# ...
